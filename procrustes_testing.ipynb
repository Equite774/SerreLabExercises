# %%
import numpy as np
import torch
import torchvision
import sys
sys.path.append("netrep")
from netrep.metrics import LinearMetric
sys.path.append("..")
from Procrustes import ProcrustesDistance

# %%
random_state = torch.manual_seed(17)
angles = torch.linspace(0, 2*torch.pi, steps=181)

def givens_rotation(p, i, j, theta):
    """Return a p×p rotation in the (i,j) plane by angle theta."""
    G = torch.eye(p)
    c, s = torch.cos(theta), torch.sin(theta)
    G[i, i] = c; G[j, j] = c
    G[i, j] = -s; G[j, i] = s
    return G

def compare_metrics(dimensions=256, neurons=32):
    """Compare LinearMetric and ProcrustesDistance on rotated data."""
    X = torch.randn(dimensions, neurons, requires_grad=True)
    lookup = {}
    for theta in angles:
        Q = givens_rotation(neurons, 7, 15, theta)   # rotate in plane (0,1)
        Y = X @ Q + torch.randn(dimensions, neurons) * 0.1
        proc_metric = LinearMetric(alpha=1.0, center_columns=True, score_method='euclidean')
        proc_metric.fit(X.detach().numpy(), Y.detach().numpy())
        dist = proc_metric.score(X.detach().numpy(), Y.detach().numpy())
        diff_metric = ProcrustesDistance()
        loss = diff_metric(X, Y)
        lookup[theta.item()] = (dist, loss.item())
    return lookup

# %%
random_state = torch.manual_seed(17)
for dimensions in [64, 128, 256]:
    for neurons in [16, 32, 64]:
        print(f"Dimensions: {dimensions}, Neurons: {neurons}")
        lookup = compare_metrics(dimensions=dimensions, neurons=neurons)
        for theta in angles:
            print(f"DxN: {dimensions}x{neurons}, Angle: {theta.item():.2f}, LinearMetric: {lookup[theta.item()][0]:.4f}, ProcrustesDistance: {lookup[theta.item()][1]:.4f}, Diff: {abs(lookup[theta.item()][0]-lookup[theta.item()][1]):.4f}") if abs(lookup[theta.item()][0]-lookup[theta.item()][1]) > 1e-4 else None
        print("\n")
# Out:
# Dimensions: 64, Neurons: 16
#
#
# Dimensions: 64, Neurons: 32
#
#
# Dimensions: 64, Neurons: 64
#
#
# Dimensions: 128, Neurons: 16
#
#
# Dimensions: 128, Neurons: 32
#
#
# Dimensions: 128, Neurons: 64
#
#
# Dimensions: 256, Neurons: 16
#
#
# Dimensions: 256, Neurons: 32
#
#
# Dimensions: 256, Neurons: 64

# %%
for theta in angles:
    print(f"Angle: {theta.item():.2f}, LinearMetric: {lookup[theta.item()][0]:.4f}, ProcrustesDistance: {lookup[theta.item()][1]:.4f}, Diff: {abs(lookup[theta.item()][0]-lookup[theta.item()][1]):.4f}")
# Out:
# Angle: 0.00, LinearMetric: 11.9621, ProcrustesDistance: 11.9621, Diff: 0.0000
# Angle: 0.03, LinearMetric: 11.9358, ProcrustesDistance: 11.9358, Diff: 0.0000
# Angle: 0.07, LinearMetric: 11.8997, ProcrustesDistance: 11.8997, Diff: 0.0000
# Angle: 0.10, LinearMetric: 11.9011, ProcrustesDistance: 11.9011, Diff: 0.0000
# Angle: 0.14, LinearMetric: 11.9615, ProcrustesDistance: 11.9615, Diff: 0.0000
# Angle: 0.17, LinearMetric: 11.7043, ProcrustesDistance: 11.7043, Diff: 0.0000
# Angle: 0.21, LinearMetric: 12.1138, ProcrustesDistance: 12.1138, Diff: 0.0000
# Angle: 0.24, LinearMetric: 11.9534, ProcrustesDistance: 11.9534, Diff: 0.0000
# Angle: 0.28, LinearMetric: 12.0672, ProcrustesDistance: 12.0672, Diff: 0.0000
# Angle: 0.31, LinearMetric: 11.9173, ProcrustesDistance: 11.9173, Diff: 0.0000
# Angle: 0.35, LinearMetric: 11.9462, ProcrustesDistance: 11.9462, Diff: 0.0000
# Angle: 0.38, LinearMetric: 12.0599, ProcrustesDistance: 12.0599, Diff: 0.0000
# Angle: 0.42, LinearMetric: 12.0153, ProcrustesDistance: 12.0153, Diff: 0.0000
# Angle: 0.45, LinearMetric: 11.9454, ProcrustesDistance: 11.9454, Diff: 0.0000
# Angle: 0.49, LinearMetric: 11.9875, ProcrustesDistance: 11.9875, Diff: 0.0000
# Angle: 0.52, LinearMetric: 12.0626, ProcrustesDistance: 12.0626, Diff: 0.0000
# Angle: 0.56, LinearMetric: 11.9026, ProcrustesDistance: 11.9026, Diff: 0.0000
# Angle: 0.59, LinearMetric: 11.8386, ProcrustesDistance: 11.8386, Diff: 0.0000
# Angle: 0.63, LinearMetric: 11.9165, ProcrustesDistance: 11.9165, Diff: 0.0000
# Angle: 0.66, LinearMetric: 11.8677, ProcrustesDistance: 11.8677, Diff: 0.0000
# Angle: 0.70, LinearMetric: 11.8784, ProcrustesDistance: 11.8784, Diff: 0.0000
# Angle: 0.73, LinearMetric: 12.0716, ProcrustesDistance: 12.0716, Diff: 0.0000
# Angle: 0.77, LinearMetric: 11.9501, ProcrustesDistance: 11.9501, Diff: 0.0000
# Angle: 0.80, LinearMetric: 12.0817, ProcrustesDistance: 12.0817, Diff: 0.0000
# Angle: 0.84, LinearMetric: 12.0367, ProcrustesDistance: 12.0367, Diff: 0.0000
# Angle: 0.87, LinearMetric: 12.0606, ProcrustesDistance: 12.0606, Diff: 0.0000
# Angle: 0.91, LinearMetric: 11.9212, ProcrustesDistance: 11.9212, Diff: 0.0000
# Angle: 0.94, LinearMetric: 11.8970, ProcrustesDistance: 11.8970, Diff: 0.0000
# Angle: 0.98, LinearMetric: 12.0171, ProcrustesDistance: 12.0171, Diff: 0.0000
# Angle: 1.01, LinearMetric: 11.9525, ProcrustesDistance: 11.9525, Diff: 0.0000
# Angle: 1.05, LinearMetric: 11.9210, ProcrustesDistance: 11.9210, Diff: 0.0000
# Angle: 1.08, LinearMetric: 11.9954, ProcrustesDistance: 11.9954, Diff: 0.0000
# Angle: 1.12, LinearMetric: 11.9764, ProcrustesDistance: 11.9764, Diff: 0.0000
# Angle: 1.15, LinearMetric: 12.0389, ProcrustesDistance: 12.0389, Diff: 0.0000
# Angle: 1.19, LinearMetric: 12.0240, ProcrustesDistance: 12.0240, Diff: 0.0000
# Angle: 1.22, LinearMetric: 12.0922, ProcrustesDistance: 12.0922, Diff: 0.0000
# Angle: 1.26, LinearMetric: 11.7428, ProcrustesDistance: 11.7428, Diff: 0.0000
# Angle: 1.29, LinearMetric: 11.9799, ProcrustesDistance: 11.9799, Diff: 0.0000
# Angle: 1.33, LinearMetric: 11.9091, ProcrustesDistance: 11.9091, Diff: 0.0000
# Angle: 1.36, LinearMetric: 11.8990, ProcrustesDistance: 11.8990, Diff: 0.0000
# Angle: 1.40, LinearMetric: 12.0113, ProcrustesDistance: 12.0113, Diff: 0.0000
# Angle: 1.43, LinearMetric: 11.9788, ProcrustesDistance: 11.9788, Diff: 0.0000
# Angle: 1.47, LinearMetric: 11.8797, ProcrustesDistance: 11.8797, Diff: 0.0000
# Angle: 1.50, LinearMetric: 12.0469, ProcrustesDistance: 12.0469, Diff: 0.0000
# Angle: 1.54, LinearMetric: 12.0321, ProcrustesDistance: 12.0321, Diff: 0.0000
# Angle: 1.57, LinearMetric: 11.9257, ProcrustesDistance: 11.9257, Diff: 0.0000
# Angle: 1.61, LinearMetric: 11.8876, ProcrustesDistance: 11.8876, Diff: 0.0000
# Angle: 1.64, LinearMetric: 11.9017, ProcrustesDistance: 11.9017, Diff: 0.0000
# Angle: 1.68, LinearMetric: 11.8391, ProcrustesDistance: 11.8391, Diff: 0.0000
# Angle: 1.71, LinearMetric: 12.0355, ProcrustesDistance: 12.0355, Diff: 0.0000
# Angle: 1.75, LinearMetric: 12.0740, ProcrustesDistance: 12.0740, Diff: 0.0000
# Angle: 1.78, LinearMetric: 12.0349, ProcrustesDistance: 12.0349, Diff: 0.0000
# Angle: 1.82, LinearMetric: 11.9111, ProcrustesDistance: 11.9111, Diff: 0.0000
# Angle: 1.85, LinearMetric: 11.9756, ProcrustesDistance: 11.9756, Diff: 0.0000
# Angle: 1.88, LinearMetric: 11.9674, ProcrustesDistance: 11.9674, Diff: 0.0000
# Angle: 1.92, LinearMetric: 12.0567, ProcrustesDistance: 12.0567, Diff: 0.0000
# Angle: 1.95, LinearMetric: 11.9463, ProcrustesDistance: 11.9463, Diff: 0.0000
# Angle: 1.99, LinearMetric: 11.9482, ProcrustesDistance: 11.9482, Diff: 0.0000
# Angle: 2.02, LinearMetric: 11.8572, ProcrustesDistance: 11.8572, Diff: 0.0000
# Angle: 2.06, LinearMetric: 11.9257, ProcrustesDistance: 11.9257, Diff: 0.0000
# Angle: 2.09, LinearMetric: 11.9875, ProcrustesDistance: 11.9875, Diff: 0.0000
# Angle: 2.13, LinearMetric: 11.9987, ProcrustesDistance: 11.9987, Diff: 0.0000
# Angle: 2.16, LinearMetric: 11.9758, ProcrustesDistance: 11.9758, Diff: 0.0000
# Angle: 2.20, LinearMetric: 11.9497, ProcrustesDistance: 11.9497, Diff: 0.0000
# Angle: 2.23, LinearMetric: 12.0166, ProcrustesDistance: 12.0166, Diff: 0.0000
# Angle: 2.27, LinearMetric: 11.9796, ProcrustesDistance: 11.9796, Diff: 0.0000
# Angle: 2.30, LinearMetric: 11.8617, ProcrustesDistance: 11.8617, Diff: 0.0000
# Angle: 2.34, LinearMetric: 11.8252, ProcrustesDistance: 11.8252, Diff: 0.0000
# Angle: 2.37, LinearMetric: 11.9930, ProcrustesDistance: 11.9930, Diff: 0.0000
# Angle: 2.41, LinearMetric: 11.8654, ProcrustesDistance: 11.8654, Diff: 0.0000
# Angle: 2.44, LinearMetric: 11.7953, ProcrustesDistance: 11.7953, Diff: 0.0000
# Angle: 2.48, LinearMetric: 12.0012, ProcrustesDistance: 12.0012, Diff: 0.0000
# Angle: 2.51, LinearMetric: 11.9331, ProcrustesDistance: 11.9331, Diff: 0.0000
# Angle: 2.55, LinearMetric: 11.8326, ProcrustesDistance: 11.8326, Diff: 0.0000
# Angle: 2.58, LinearMetric: 11.9098, ProcrustesDistance: 11.9098, Diff: 0.0000
# Angle: 2.62, LinearMetric: 11.9809, ProcrustesDistance: 11.9809, Diff: 0.0000
# Angle: 2.65, LinearMetric: 11.9270, ProcrustesDistance: 11.9270, Diff: 0.0000
# Angle: 2.69, LinearMetric: 11.9268, ProcrustesDistance: 11.9268, Diff: 0.0000
# Angle: 2.72, LinearMetric: 11.9147, ProcrustesDistance: 11.9147, Diff: 0.0000
# Angle: 2.76, LinearMetric: 11.8969, ProcrustesDistance: 11.8969, Diff: 0.0000
# Angle: 2.79, LinearMetric: 11.8988, ProcrustesDistance: 11.8988, Diff: 0.0000
# Angle: 2.83, LinearMetric: 11.8785, ProcrustesDistance: 11.8785, Diff: 0.0000
# Angle: 2.86, LinearMetric: 11.9350, ProcrustesDistance: 11.9350, Diff: 0.0000
# Angle: 2.90, LinearMetric: 11.8542, ProcrustesDistance: 11.8542, Diff: 0.0000
# Angle: 2.93, LinearMetric: 12.0118, ProcrustesDistance: 12.0118, Diff: 0.0000
# Angle: 2.97, LinearMetric: 11.9132, ProcrustesDistance: 11.9132, Diff: 0.0000
# Angle: 3.00, LinearMetric: 12.0077, ProcrustesDistance: 12.0077, Diff: 0.0000
# Angle: 3.04, LinearMetric: 11.9132, ProcrustesDistance: 11.9132, Diff: 0.0000
# Angle: 3.07, LinearMetric: 11.9203, ProcrustesDistance: 11.9203, Diff: 0.0000
# Angle: 3.11, LinearMetric: 12.0193, ProcrustesDistance: 12.0193, Diff: 0.0000
# Angle: 3.14, LinearMetric: 11.9590, ProcrustesDistance: 11.9590, Diff: 0.0000
# Angle: 3.18, LinearMetric: 11.9532, ProcrustesDistance: 11.9532, Diff: 0.0000
# Angle: 3.21, LinearMetric: 11.9766, ProcrustesDistance: 11.9766, Diff: 0.0000
# Angle: 3.25, LinearMetric: 12.0195, ProcrustesDistance: 12.0195, Diff: 0.0000
# Angle: 3.28, LinearMetric: 11.8857, ProcrustesDistance: 11.8857, Diff: 0.0000
# Angle: 3.32, LinearMetric: 11.9282, ProcrustesDistance: 11.9282, Diff: 0.0000
# Angle: 3.35, LinearMetric: 11.9219, ProcrustesDistance: 11.9219, Diff: 0.0000
# Angle: 3.39, LinearMetric: 11.9674, ProcrustesDistance: 11.9674, Diff: 0.0000
# Angle: 3.42, LinearMetric: 11.9536, ProcrustesDistance: 11.9536, Diff: 0.0000
# Angle: 3.46, LinearMetric: 12.0419, ProcrustesDistance: 12.0419, Diff: 0.0000
# Angle: 3.49, LinearMetric: 12.0151, ProcrustesDistance: 12.0151, Diff: 0.0000
# Angle: 3.53, LinearMetric: 12.0619, ProcrustesDistance: 12.0619, Diff: 0.0000
# Angle: 3.56, LinearMetric: 11.9248, ProcrustesDistance: 11.9248, Diff: 0.0000
# Angle: 3.60, LinearMetric: 12.0267, ProcrustesDistance: 12.0267, Diff: 0.0000
# Angle: 3.63, LinearMetric: 11.8765, ProcrustesDistance: 11.8765, Diff: 0.0000
# Angle: 3.67, LinearMetric: 11.9883, ProcrustesDistance: 11.9883, Diff: 0.0000
# Angle: 3.70, LinearMetric: 11.9003, ProcrustesDistance: 11.9003, Diff: 0.0000
# Angle: 3.74, LinearMetric: 11.9501, ProcrustesDistance: 11.9501, Diff: 0.0000
# Angle: 3.77, LinearMetric: 11.9348, ProcrustesDistance: 11.9348, Diff: 0.0000
# Angle: 3.80, LinearMetric: 11.9508, ProcrustesDistance: 11.9508, Diff: 0.0000
# Angle: 3.84, LinearMetric: 11.9894, ProcrustesDistance: 11.9894, Diff: 0.0000
# Angle: 3.87, LinearMetric: 11.9910, ProcrustesDistance: 11.9910, Diff: 0.0000
# Angle: 3.91, LinearMetric: 11.8932, ProcrustesDistance: 11.8932, Diff: 0.0000
# Angle: 3.94, LinearMetric: 11.9189, ProcrustesDistance: 11.9189, Diff: 0.0000
# Angle: 3.98, LinearMetric: 11.9630, ProcrustesDistance: 11.9630, Diff: 0.0000
# Angle: 4.01, LinearMetric: 11.8435, ProcrustesDistance: 11.8435, Diff: 0.0000
# Angle: 4.05, LinearMetric: 11.9178, ProcrustesDistance: 11.9178, Diff: 0.0000
# Angle: 4.08, LinearMetric: 11.9888, ProcrustesDistance: 11.9888, Diff: 0.0000
# Angle: 4.12, LinearMetric: 11.8781, ProcrustesDistance: 11.8781, Diff: 0.0000
# Angle: 4.15, LinearMetric: 12.0875, ProcrustesDistance: 12.0875, Diff: 0.0000
# Angle: 4.19, LinearMetric: 12.0854, ProcrustesDistance: 12.0854, Diff: 0.0000
# Angle: 4.22, LinearMetric: 12.0663, ProcrustesDistance: 12.0663, Diff: 0.0000
# Angle: 4.26, LinearMetric: 12.0406, ProcrustesDistance: 12.0406, Diff: 0.0000
# Angle: 4.29, LinearMetric: 11.8878, ProcrustesDistance: 11.8878, Diff: 0.0000
# Angle: 4.33, LinearMetric: 11.9121, ProcrustesDistance: 11.9121, Diff: 0.0000
# Angle: 4.36, LinearMetric: 12.0565, ProcrustesDistance: 12.0565, Diff: 0.0000
# Angle: 4.40, LinearMetric: 12.0389, ProcrustesDistance: 12.0389, Diff: 0.0000
# Angle: 4.43, LinearMetric: 11.9083, ProcrustesDistance: 11.9083, Diff: 0.0000
# Angle: 4.47, LinearMetric: 11.8335, ProcrustesDistance: 11.8335, Diff: 0.0000
# Angle: 4.50, LinearMetric: 11.8593, ProcrustesDistance: 11.8593, Diff: 0.0000
# Angle: 4.54, LinearMetric: 12.1426, ProcrustesDistance: 12.1426, Diff: 0.0000
# Angle: 4.57, LinearMetric: 11.8181, ProcrustesDistance: 11.8181, Diff: 0.0000
# Angle: 4.61, LinearMetric: 11.9359, ProcrustesDistance: 11.9359, Diff: 0.0000
# Angle: 4.64, LinearMetric: 12.0856, ProcrustesDistance: 12.0856, Diff: 0.0000
# Angle: 4.68, LinearMetric: 12.0564, ProcrustesDistance: 12.0564, Diff: 0.0000
# Angle: 4.71, LinearMetric: 11.9006, ProcrustesDistance: 11.9006, Diff: 0.0000
# Angle: 4.75, LinearMetric: 12.0460, ProcrustesDistance: 12.0460, Diff: 0.0000
# Angle: 4.78, LinearMetric: 11.9304, ProcrustesDistance: 11.9304, Diff: 0.0000
# Angle: 4.82, LinearMetric: 11.9545, ProcrustesDistance: 11.9545, Diff: 0.0000
# Angle: 4.85, LinearMetric: 12.0277, ProcrustesDistance: 12.0277, Diff: 0.0000
# Angle: 4.89, LinearMetric: 11.9619, ProcrustesDistance: 11.9619, Diff: 0.0000
# Angle: 4.92, LinearMetric: 12.0462, ProcrustesDistance: 12.0462, Diff: 0.0000
# Angle: 4.96, LinearMetric: 12.0777, ProcrustesDistance: 12.0777, Diff: 0.0000
# Angle: 4.99, LinearMetric: 11.8251, ProcrustesDistance: 11.8251, Diff: 0.0000
# Angle: 5.03, LinearMetric: 12.0027, ProcrustesDistance: 12.0027, Diff: 0.0000
# Angle: 5.06, LinearMetric: 12.0247, ProcrustesDistance: 12.0247, Diff: 0.0000
# Angle: 5.10, LinearMetric: 11.9938, ProcrustesDistance: 11.9938, Diff: 0.0000
# Angle: 5.13, LinearMetric: 11.9802, ProcrustesDistance: 11.9802, Diff: 0.0000
# Angle: 5.17, LinearMetric: 12.0203, ProcrustesDistance: 12.0203, Diff: 0.0000
# Angle: 5.20, LinearMetric: 12.0421, ProcrustesDistance: 12.0421, Diff: 0.0000
# Angle: 5.24, LinearMetric: 11.9795, ProcrustesDistance: 11.9795, Diff: 0.0000
# Angle: 5.27, LinearMetric: 12.0652, ProcrustesDistance: 12.0652, Diff: 0.0000
# Angle: 5.31, LinearMetric: 11.8627, ProcrustesDistance: 11.8627, Diff: 0.0000
# Angle: 5.34, LinearMetric: 11.9904, ProcrustesDistance: 11.9904, Diff: 0.0000
# Angle: 5.38, LinearMetric: 11.9756, ProcrustesDistance: 11.9756, Diff: 0.0000
# Angle: 5.41, LinearMetric: 11.9821, ProcrustesDistance: 11.9821, Diff: 0.0000
# Angle: 5.45, LinearMetric: 12.0452, ProcrustesDistance: 12.0452, Diff: 0.0000
# Angle: 5.48, LinearMetric: 11.9435, ProcrustesDistance: 11.9435, Diff: 0.0000
# Angle: 5.52, LinearMetric: 11.8583, ProcrustesDistance: 11.8583, Diff: 0.0000
# Angle: 5.55, LinearMetric: 11.9485, ProcrustesDistance: 11.9485, Diff: 0.0000
# Angle: 5.59, LinearMetric: 11.9620, ProcrustesDistance: 11.9620, Diff: 0.0000
# Angle: 5.62, LinearMetric: 11.9406, ProcrustesDistance: 11.9406, Diff: 0.0000
# Angle: 5.65, LinearMetric: 12.0181, ProcrustesDistance: 12.0181, Diff: 0.0000
# Angle: 5.69, LinearMetric: 11.9788, ProcrustesDistance: 11.9788, Diff: 0.0000
# Angle: 5.72, LinearMetric: 12.0350, ProcrustesDistance: 12.0350, Diff: 0.0000
# Angle: 5.76, LinearMetric: 11.8946, ProcrustesDistance: 11.8946, Diff: 0.0000
# Angle: 5.79, LinearMetric: 11.8389, ProcrustesDistance: 11.8389, Diff: 0.0000
# Angle: 5.83, LinearMetric: 11.9805, ProcrustesDistance: 11.9805, Diff: 0.0000
# Angle: 5.86, LinearMetric: 11.8890, ProcrustesDistance: 11.8890, Diff: 0.0000
# Angle: 5.90, LinearMetric: 12.0239, ProcrustesDistance: 12.0239, Diff: 0.0000
# Angle: 5.93, LinearMetric: 11.9656, ProcrustesDistance: 11.9656, Diff: 0.0000
# Angle: 5.97, LinearMetric: 12.0217, ProcrustesDistance: 12.0217, Diff: 0.0000
# Angle: 6.00, LinearMetric: 11.9725, ProcrustesDistance: 11.9725, Diff: 0.0000
# Angle: 6.04, LinearMetric: 11.9569, ProcrustesDistance: 11.9569, Diff: 0.0000
# Angle: 6.07, LinearMetric: 12.0178, ProcrustesDistance: 12.0178, Diff: 0.0000
# Angle: 6.11, LinearMetric: 11.9745, ProcrustesDistance: 11.9745, Diff: 0.0000
# Angle: 6.14, LinearMetric: 11.9973, ProcrustesDistance: 11.9973, Diff: 0.0000
# Angle: 6.18, LinearMetric: 12.0070, ProcrustesDistance: 12.0070, Diff: 0.0000
# Angle: 6.21, LinearMetric: 12.0748, ProcrustesDistance: 12.0748, Diff: 0.0000
# Angle: 6.25, LinearMetric: 12.0364, ProcrustesDistance: 12.0364, Diff: 0.0000
# Angle: 6.28, LinearMetric: 11.8794, ProcrustesDistance: 11.8794, Diff: 0.0000

# %%
X = torch.randn(32, 32, requires_grad=True)
Y = X @ givens_rotation(32, 7, 15, angles[4]) + torch.randn(32, 32) * 0.1
metric = ProcrustesDistance()
loss = metric(X, Y)
print(f"Procrustes Distance: {loss.item():.4f}")
# Out:
# Procrustes Distance: 2.3323

# %%
loss.backward(retain_graph=True)
print(X.grad, Y.grad)
# Out:
# tensor([[ 0.0011, -0.0026,  0.0010,  ..., -0.0024, -0.0049,  0.0045],
#         [-0.0021,  0.0022, -0.0023,  ...,  0.0032,  0.0024, -0.0078],
#         [-0.0021, -0.0003, -0.0006,  ...,  0.0025, -0.0052, -0.0006],
#         ...,
#         [ 0.0026,  0.0009,  0.0040,  ..., -0.0090, -0.0015,  0.0026],
#         [-0.0005, -0.0033, -0.0005,  ...,  0.0029,  0.0022,  0.0003],
#         [ 0.0007,  0.0021,  0.0004,  ...,  0.0041,  0.0054, -0.0033]]) None
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_80169/2679001290.py:2: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/build/aten/src/ATen/core/TensorBody.h:494.)
#   print(X.grad, Y.grad)

# %%
import torchvision.datasets as datasets
import torchvision.transforms as transforms

datasets.MNIST.mirrors = ["https://ossci-datasets.s3.amazonaws.com/mnist"]
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transforms.ToTensor())
print(f"MNIST Trainset Size: {len(mnist_trainset)}, Testset Size: {len(mnist_testset)}")
# Out:
# MNIST Trainset Size: 60000, Testset Size: 10000

# %%
# Basic 2 layer MLP
import torch.nn as nn
import torch.nn.functional as F
class SimpleMLP(nn.Module):
    def __init__(self, input_size=28*28, output_size=10):
        super(SimpleMLP, self).__init__()
        self.fc1 = nn.Linear(input_size, output_size)

    def forward(self, x):
        x = x.view(-1, 28*28)  # Flatten the input
        x = self.fc1(x)
        return x

# %%
# Train the MLP on MNIST
from torch.utils.data import DataLoader, random_split
import torch.nn.functional as F

train_loader = DataLoader(mnist_trainset, batch_size=64, shuffle=True)

# Split test set into validation and test sets
val_size = 2000
test_size = len(mnist_testset) - val_size
val_set, test_set = random_split(mnist_testset, [val_size, test_size])

val_loader = DataLoader(val_set, batch_size=1000, shuffle=False)
test_loader = DataLoader(test_set, batch_size=1000, shuffle=False)

model = SimpleMLP()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

def calculate_accuracy(loader, model):
    """Calculate accuracy on a dataset."""
    model.eval()
    correct = 0
    total = 0
    total_loss = 0
    with torch.no_grad():
        for data, target in loader:
            output = model(data)
            loss = criterion(output, target)
            total_loss += loss.item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            total += target.size(0)
    return total_loss / len(loader), 100. * correct / total

# Training loop
for epoch in range(1, 6):  # 5 epochs
    model.train()
    train_loss = 0
    train_correct = 0
    train_total = 0
    
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        pred = output.argmax(dim=1, keepdim=True)
        train_correct += pred.eq(target.view_as(pred)).sum().item()
        train_total += target.size(0)
    
    # Calculate average training metrics
    avg_train_loss = train_loss / len(train_loader)
    train_accuracy = 100. * train_correct / train_total
    
    # Calculate validation metrics
    val_loss, val_accuracy = calculate_accuracy(val_loader, model)
    
    print(f"Epoch {epoch}, Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%")

# Testing loop
test_loss, test_accuracy = calculate_accuracy(test_loader, model)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Epoch 1, Train Loss: 0.5423, Train Acc: 86.98%, Val Loss: 0.3317, Val Acc: 91.10%
# Epoch 2, Train Loss: 0.3234, Train Acc: 91.03%, Val Loss: 0.2960, Val Acc: 91.50%
# Epoch 3, Train Loss: 0.2953, Train Acc: 91.84%, Val Loss: 0.2805, Val Acc: 92.35%
# Epoch 4, Train Loss: 0.2819, Train Acc: 92.13%, Val Loss: 0.2795, Val Acc: 92.25%
# Epoch 5, Train Loss: 0.2733, Train Acc: 92.37%, Val Loss: 0.2716, Val Acc: 92.15%
# Test Loss: 0.2694, Test Accuracy: 92.49%

# %%
print(model)
W, b = model.fc1.weight, model.fc1.bias
print(W.shape, b.shape)
B = torch.cat([W, b.unsqueeze(1)], dim=1)  # Combine weights and bias
print(B.shape)  # Should be [10, 785]

# Recover
W_recovered = B[:, :-1]  # All columns except the last one
b_recovered = B[:, -1]   # Only the last column
assert torch.allclose(W, W_recovered)
assert torch.allclose(b, b_recovered)
# Out:
# SimpleMLP(
#   (fc1): Linear(in_features=784, out_features=10, bias=True)
# )
# torch.Size([10, 784]) torch.Size([10])
# torch.Size([10, 785])

# %%
A = torch.randn(10, 785, requires_grad=True)
gradient = torch.optim.Adam([A], lr=0.01)
loss_fn = ProcrustesDistance()

# Make A look like B
for _ in range(700):
    gradient.zero_grad()
    loss = loss_fn(A, B)
    if _ % 100 == 0:
        proc_metric = LinearMetric(alpha=1.0, center_columns=True, score_method='euclidean')
        proc_metric.fit(A.detach().numpy(), B.detach().numpy())
        dist = proc_metric.score(A.detach().numpy(), B.detach().numpy())
    loss.backward()
    gradient.step()
    if _ % 100 == 0:
        print(f"Procrustes Distance: {loss.item():.4f}, LinearMetric Distance: {dist:.4f}")
print(f"Final Procrustes Distance between A and B: {loss_fn(A, B).item():.4f}")
# Out:
# Procrustes Distance: 68.2172, LinearMetric Distance: 68.2172
# Procrustes Distance: 12.8499, LinearMetric Distance: 12.8499
# Procrustes Distance: 0.0448, LinearMetric Distance: 0.0448
# Procrustes Distance: 0.0302, LinearMetric Distance: 0.0302
# Procrustes Distance: 0.0306, LinearMetric Distance: 0.0306
# Procrustes Distance: 0.0391, LinearMetric Distance: 0.0391
# Procrustes Distance: 0.0239, LinearMetric Distance: 0.0239
# Final Procrustes Distance between A and B: 0.0258

# %%
print(A.shape)
W_prime, b_prime = A[:, :-1], A[:, -1]
new_model = SimpleMLP()
new_model.fc1.weight.data = W_prime
new_model.fc1.bias.data = b_prime
new_test_loss, new_test_accuracy = calculate_accuracy(test_loader, new_model)
print(f"New Model Test Loss: {new_test_loss:.4f}, New Model Test Accuracy: {new_test_accuracy:.2f}%")
# Out:
# torch.Size([10, 785])
# New Model Test Loss: 3.3069, New Model Test Accuracy: 9.69%
